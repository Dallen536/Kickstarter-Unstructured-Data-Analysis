# %%
# !unzip ./ks-projects-201801.csv.zip
# Out:
# Archive:  ./ks-projects-201801.csv.zip
#   inflating: ks-projects-201801.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('ks-projects-201801.csv')
data.head(100)
# Out:
#             ID                                               name  \
# 0   1000002330                    The Songs of Adelaide & Abullah
# 1   1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2   1000004038                                     Where is Hank?
# 3   1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4   1000011046  Community Film Project: The Art of Neighborhoo...
# ..         ...                                                ...
# 95  1000386601    Los Angeles International Student Film Festival
# 96  1000389241                     Bob Contemplates Ending It All
# 97  1000392220                                 The Girls Bathroom
# 98   100039820                  Best Spray Bottle Ever - SureShot
# 99  1000399155                                        New Lasagna
#
#           category main_category currency    deadline     goal  \
# 0           Poetry    Publishing      GBP  2015-10-09   1000.0
# ...

# %%
mindate = data['launched'].min()
maxdate = data['launched'].max()
print(f' the earliest date is {mindate} and the latest date is {maxdate}')
# remove the outliers from the dataset such as the 1970 dat
# Out:
#  the earliest date is 1970-01-01 01:00:00 and the latest date is 2018-01-02 15:02:31

# %%
data['name'].count()
# Out:
# 378657
